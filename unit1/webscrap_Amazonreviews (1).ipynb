# %%
from bs4 import BeautifulSoup as bs
# extract information from the HTML or XML files
# functions to navigate, search or modify
# https://docs.python.org/3/howto/urllib2.html
from urllib.request import urlopen
# opens urls

url = "https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
#returns an httpresponse object
page = urlopen(url)
print(page)

# %%
#To extract the HTML from the page, first use the 
#HTTPResponse object’s .read() method, which returns a sequence of bytes. 
#Then use .decode() to decode the bytes to a string using UTF-8:
html = page.read().decode("utf-8")
soup = bs(html, "html.parser") # BeautifulSoup object from an HTML
print(soup.get_text())
# Out:
# Amazon.in:Customer reviews: Apple iPhone 11 (128GB) - Black (Includes EarPods, Power Adapter)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
#
#
#
#
#
#
#
#
#
#
# .in
#
#
#
#
#
#
#
#
#
#                    Delivering to Mumbai 400001
#
#
#                    Sign in to update your location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All
#
#
# Select the department you want to search in
#
# All Categories
# Alexa Skills
# Amazon Devices
# Amazon Fashion
# Amazon Fresh
# Amazon Pharmacy
# Appliances
# Apps & Games
# Audible Audiobooks
# Baby
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Collectibles
# Computers & Accessories
# Electronics
# Furniture
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Industrial & Scientific
# Jewellery
# Kindle Store
# Luggage & Bags
# Luxury Beauty
# Movies & TV Shows
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
from bs4 import BeautifulSoup

html = """
<html>
    <body>
        <p>This is some text.</p>
        <p>This is some more text.</p>
    </body>
</html>
"""

soup1 = BeautifulSoup(html, "html.parser")
text = soup1.get_text()

print(text)
# Out:
# This is some text.
# This is some more text.

# %%
print(soup1)
# Out:
# <html>
# <body>
# <p>This is some text.</p>
# <p>This is some more text.</p>
# </body>
# </html>

# %%
print(soup1.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    This is some text.
#   </p>
#   <p>
#    This is some more text.
#   </p>
#  </body>
# </html>

# %%
soup1
# Out:
# <html>
# <body>
# <p>This is some text.</p>
# <p>This is some more text.</p>
# </body>
# </html>

# %% [markdown]
# The prettify() method will turn a BeautifulSoup parse tree into a nicely formatted Unicode string, with a separate line for each tag and each string.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# ...

# %%
# find all tags with that specific name
images=soup.find_all("img")
images
# Out:
# [<img alt="" src="https://m.media-amazon.com/images/G/31/social_share/amazon_logo._CB633266945_.png" style="display:none"/>,
#  <img alt="" src="https://m.media-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-hm-dsk-reorg._CB405936311_.png" style="display:none">
#  <script type="text/javascript">var nav_t_after_preload_sprite = + new Date();</script>
#  <script>
#  (window.AmazonUIPageJS ? AmazonUIPageJS : P).when('navCF').execute(function() {
#    (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-eu.ssl-images-amazon.com/images/I/41W974vG8QL._RC|71zzjyvEIHL.js,01F+A05ogQL.js,01phmzCOwJL.js,01eOvPdxG7L.js,71HGwLRNwQL.js,41306Iio4NL.js,115pV8Rl02L.js,01+pnQJuQ0L.js,21rDHgaooIL.js,41LFml+7fVL.js,51t-JTxfnwL.js,317BC63dC8L.js,11lEMI5MhIL.js,31c7Fn9h9gL.js,01LEzWzrPZL.js,01AqeWA7PKL.js_.js?AUIClients/NavDesktopUberAsset&ADj+mKrH#desktop.language-en.in.488400-T1.488413-T1.366740-T1.310484-T1.472106-T1');
#  });
#  </script>
# ...

# %%
for image in images:
    print(image['src'])
# Out:
# https://m.media-amazon.com/images/G/31/social_share/amazon_logo._CB633266945_.png
# https://m.media-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-hm-dsk-reorg._CB405936311_.png
# https://m.media-amazon.com/images/G/31/Gateway_IN/testing/NewLaunches_400x39._CB593645585_.jpg
# https://m.media-amazon.com/images/I/414Z3g1cIbL._AC_US60_SCLZZZZZZZ__.jpg
# https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif
# https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png
# https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif
# https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png
# https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif
# https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/default._CR0,0,1024,1024_SX48_.png
# ...

# %%
# finds table
table = soup.find('table')
print(table)
# Out:
# <table class="a-normal a-spacing-none" id="histogramTable" role="presentation">
# <table class="a-normal a-align-center a-spacing-base" id="histogramTable">
# <tr aria-label="75% of reviews have 5 stars" class="a-histogram-row a-align-center" data-reftag="" data-reviews-state-param='{"filterByStar":"five_star", "pageNumber":"1"}'>
# <td class="aok-nowrap">
# <span class="a-size-base">
# <a aria-disabled="true" class="a-link-normal 5star" href="/product-reviews/B07XVLW7YK/ref=acr_dp_hist_5?ie=UTF8&amp;filterByStar=five_star&amp;reviewerType=all_reviews#reviews-filter-bar" title="75% of reviews have 5 stars">
#             5 star
#           </a>
# </span>
# <span class="a-letter-space"></span>
# </td>
# <td class="a-span10">
# <a aria-disabled="true" aria-hidden="true" class="a-link-normal" href="/product-reviews/B07XVLW7YK/ref=acr_dp_hist_5?ie=UTF8&amp;filterByStar=five_star&amp;reviewerType=all_reviews#reviews-filter-bar" title="75% of reviews have 5 stars">
# ...

# %%
# to find all span tags with the class "a-profile-name"
# returns list of matching tags
Name = soup.findAll("span", {"class" : "a-profile-name"})
print(Name)
len(Name)
# Out:
# [<span class="a-profile-name">Ravi</span>, <span class="a-profile-name">Pounkumar. P</span>, <span class="a-profile-name">Ravi</span>, <span class="a-profile-name">Ravi</span>, <span class="a-profile-name">Siddhartha R.</span>, <span class="a-profile-name">vishnudathan</span>, <span class="a-profile-name">Shalini</span>, <span class="a-profile-name">Shalini</span>, <span class="a-profile-name">Susanta</span>, <span class="a-profile-name">pk2013</span>, <span class="a-profile-name">PR</span>, <span class="a-profile-name">PR</span>, <span class="a-profile-name">MSA</span>, <span class="a-profile-name">Inder Nath</span>, <span class="a-profile-name">Gaurav</span>]
# 15

# %%
Name = soup.findAll("span", {"class" : "a-profile-name"}) 
# find <span> element with attributes class = a-profile-name

# Extract name from span tag
Reviewer = []
for i in range(2,len(Name)):     
# Loop is initiated from 2 because we have to exclude the 
#Top Positive and Top Critical Review which otherwise will get repeated.
    Reviewer.append(Name[i].get_text())
    
print(Reviewer)
len(Reviewer)
# Out:
# ['Ravi', 'Ravi', 'Siddhartha R.', 'vishnudathan', 'Shalini', 'Shalini', 'Susanta', 'pk2013', 'PR', 'PR', 'MSA', 'Inder Nath', 'Gaurav']
# 13

# %%
Reviewer=list(set(Reviewer))
print(Reviewer)
len(Reviewer)
# Out:
# ['Shalini', 'Susanta', 'MSA', 'Inder Nath', 'PR', 'Siddhartha R.', 'pk2013', 'Ravi', 'Gaurav', 'vishnudathan']
# 10

# %%
# tag "i" and class name "review-rating"
Product_Rating = soup.findAll("i", {"class" : "review-rating"})
print(Product_Rating)
len(Product_Rating)
# Out:
# [<i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">4.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">3.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>, <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span><
# ...

# %%
Product_Rating = soup.findAll("i", {"class" : "review-rating"})     # find <i> element with attributes class = review-rating


Rating = []
for i in range(2,len(Product_Rating)):     # Loop is initiated from 2 because we have to exclude the Top Positive and Top Critical Review which otherwise will get repeated.
    Rating.append(Product_Rating[i].get_text())
    
print(Rating)
len(Rating)
# Out:
# ['4.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '5.0 out of 5 stars', '4.0 out of 5 stars', '5.0 out of 5 stars', '4.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars']
# 10

# %%
# tag "a" and class "review-title-content"
Review_Title = soup.findAll("a", {"class" : "review-title-content"})     # find <a> element with attributes class = review-title-content
print(Review_Title)
len(Review_Title)
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RSOQ7HNA49AT1?ASIN=B07XVLW7YK"><i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>iPhone 11 review</span>
# </a>, <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1VO13KO3KBJT1?ASIN=B07XVLW7YK"><i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i><span class="a-letter-space"></span>
# <span>Good</span>
# ...

# %%
Review_Title = soup.findAll("a", {"class" : "review-title-content"})     # find <a> element with attributes class = review-title-content

# Extract name from span tag
Review_Desc = []
for i in range(0,len(Review_Title)):
    Review_Desc.append(Review_Title[i].get_text())

# We will remove the '\n' from before and after of every Review Title
Review_Desc[:] = [i.lstrip('\n').rstrip('\n') for i in Review_Desc]

print(Review_Desc)
len(Review_Desc)
# Out:
# ['4.0 out of 5 stars\niPhone 11 review', '4.0 out of 5 stars\nGood', '4.0 out of 5 stars\nGood', '4.0 out of 5 stars\nNice quality', '5.0 out of 5 stars\nGood product', '4.0 out of 5 stars\nBeast with a limp', '5.0 out of 5 stars\nThe best iPhone - perfect combination of features!', '4.0 out of 5 stars\nSo far so good...(1 week user)', '5.0 out of 5 stars\nGood', '5.0 out of 5 stars\nAndroid user for 9 years switched to iPhone']
# 10

# %%
# Saving the Scraped Content to .csv file from 
import pandas as pd

# %%
# Make a DataFrame to add Details in it
Data = pd.DataFrame()

# %%
print(len(set(Reviewer)))
print(len(Rating))
print(len(Review_Desc))
# Out:
# 10
# 10
# 10

# %%
# Adding Review Information in DataFrame

Data['Reviewer'] = Reviewer
Data['Rating'] = Rating
Data['Desc']= Review_Desc
Data
# Out:
#         Reviewer              Rating  \
# 0        Shalini  4.0 out of 5 stars
# 1        Susanta  4.0 out of 5 stars
# 2            MSA  4.0 out of 5 stars
# 3     Inder Nath  4.0 out of 5 stars
# 4             PR  5.0 out of 5 stars
# 5  Siddhartha R.  4.0 out of 5 stars
# 6         pk2013  5.0 out of 5 stars
# 7           Ravi  4.0 out of 5 stars
# 8         Gaurav  5.0 out of 5 stars
# 9   vishnudathan  5.0 out of 5 stars
#
#                                                 Desc
# 0               4.0 out of 5 stars\niPhone 11 review
# 1                           4.0 out of 5 stars\nGood
# 2                           4.0 out of 5 stars\nGood
# 3                   4.0 out of 5 stars\nNice quality
# 4                   5.0 out of 5 stars\nGood product
# 5              4.0 out of 5 stars\nBeast with a limp
# 6  5.0 out of 5 stars\nThe best iPhone - perfect ...
# 7  4.0 out of 5 stars\nSo far so good...(1 week u...
# 8                           5.0 out of 5 stars\nGood
# ...

# %%
Data.to_csv(r'ex.csv', index= 'True')
# index=T then row index is written in csv
